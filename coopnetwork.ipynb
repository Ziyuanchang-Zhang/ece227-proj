# %%
import pandas as pd
import networkx as nx
import random
import matplotlib.pyplot as plt
import heapq
import time

# %%
df = pd.read_csv('social network dataset/ca-GrQc.csv')
# df = pd.read_csv('social network dataset/facebook_combined.csv')
G = nx.from_pandas_edgelist(df, source='Source', target='Target', create_using=nx.Graph())

p = 0.2
for u, v in G.edges():
    G[u][v]['weight'] = p

print(G.number_of_nodes(), G.number_of_edges())
# Out:
# 5242 14496

# %% [markdown]
# Independent Cascade Model

# %%
def independent_cascade(G, seeds, steps=10):
    activated = set(seeds)
    newly = list(seeds)
    for _ in range(steps):
        next_new = []
        for u in newly:
            for v in G.neighbors(u):
                if v not in activated and random.random() <= G[u][v]['weight']:
                    activated.add(v)
                    next_new.append(v)
        if not next_new:
            break
        newly = next_new
    return activated

# Monte Carlo estimation of spread
def estimate_spread(G, seeds, steps=10, mc_runs=20):
    total = 0
    for _ in range(mc_runs):
        total += len(independent_cascade(G, seeds, steps))
    return total / mc_runs

# Greedy seed selection
def greedy_seeds(G, k, steps=10, mc_runs=10):
    S = []
    spread_S = 0.0
    candidates = set(G.nodes())
    for i in range(k):
        # print(f"Greedy round {i+1}/{k}...")
        best, best_gain = None, 0.0
        for v in candidates - set(S):
            gain = estimate_spread(G, S + [v], steps, mc_runs) - spread_S
            # if gain > best_gain:
            best_gain, best = gain, v
        S.append(best)
        spread_S += best_gain
        print(f"Greedy round {i+1}: pick {best}, marginal gain={best_gain:.2f}")
    return S

# CELF (Cost-Effective Lazy Forward) seed selection
def celf_seeds(G, k, steps=10, mc_runs=20):

    heap = []
    for v in G.nodes():
        spread_v = estimate_spread(G, [v], steps, mc_runs)
        heap.append((-spread_v, v, 0))
    heapq.heapify(heap)

    S = [] #selected seeds
    spread_S = 0.0 #selected seeds spread
    lookups = 0  # number of re-evaluations

    # choose k seeds using CELF
    for round_i in range(1, k+1):
        while True:
            neg_gain, v, prev_round = heapq.heappop(heap)
            gain = -neg_gain
            # if this node v was selected in the previous round
            if prev_round == round_i - 1:
                S.append(v)
                spread_S += gain
                print(f"CELF round {round_i}: pick {v}, marginal gain={gain:.2f}")
                break
            else:
                # re-evaluate the gain of v
                lookups += 1
                new_gain = estimate_spread(G, S + [v], steps, mc_runs) - spread_S
                # push the updated gain back to the heap
                heapq.heappush(heap, (-new_gain, v, round_i - 1))

        # 选完 v 之后，继续下一轮

    print(f"Total re-evaluations: {lookups} (should be ≪ k·n)")
    return S

# M-Greedy(with CELF) seed selection
def m_greedy_seeds(G, k, steps=10, mc_runs=20):
    # Step 1: compute individual influence δ(v)
    delta = {v: estimate_spread(G, [v], steps, mc_runs) for v in G.nodes()}
    avg_infl = sum(delta.values()) / len(delta)
    # Step 2: filter nodes with δ(v) >= average
    candidates = [v for v, d in delta.items() if d >= avg_infl]
    G_sub = G.subgraph(candidates).copy()
    # Step 3: run CELF-greedy on reduced graph
    S = celf_seeds(G_sub, k, steps, mc_runs)
    return S

def d_greedy_seeds(G, k, Rs=100):
    # 1) 采样 Rs 个无向快照：每条边以 p 保留
    snapshots = []
    for _ in range(Rs):
        SG = nx.Graph()
        SG.add_nodes_from(G.nodes())
        for u, v, data in G.edges(data=True):
            if random.random() <= data['weight']:
                SG.add_edge(u, v)
        snapshots.append(SG)

    A = []  # 最终种子集
    # 对每个快照，记录当前 A 在该快照上可达的节点集合
    reachable = [set() for _ in range(Rs)]

    # 2) 迭代选 k 个种子
    for i in range(1, k+1):
        best_v, best_gain = None, -1.0

        # 对每个候选节点 v 计算增益 H_v
        for v in G.nodes():
            if v in A:
                continue
            total_gain = 0
            for j, SG in enumerate(snapshots):
                comp = nx.node_connected_component(SG, v)
                # 新增增益是 v 的连通分量去除已达集合后的大小
                total_gain += len(comp - reachable[j])
            H_v = total_gain / Rs

            if H_v > best_gain:
                best_gain, best_v = H_v, v

        # 3) 选中 best_v 并更新 reachable
        A.append(best_v)
        print(f"D-greedy round {i}: pick {best_v}, marginal gain={best_gain:.2f}")
        for j, SG in enumerate(snapshots):
            reachable[j] |= nx.node_connected_component(SG, best_v)

    return A

# Degree Discount IC seed selection
def degree_discount_ic(G, k, p):
    deg = {v: G.degree(v) for v in G.nodes()}
    t = {v: 0 for v in G.nodes()} # num of neighbors already activated
    dd = deg.copy() # Degree discount initialization
    S = []
    for i in range(k):
        # choose the node with maximum degree discount
        u = max(dd, key=lambda x: dd[x] if x not in S else -1)
        S.append(u)
        # update degree discount
        for v in G.neighbors(u):
            if v not in S:
                t[v] += 1
                dd[v] = deg[v] - 2*t[v] - (deg[v] - t[v])*t[v]*p
    return S

# Expected Benefit seed selection
def expected_benefit_seeds(G, k):
    S = []
    for _ in range(k):
        scores = {}
        for v in G.nodes():
            if v in S:
                continue
            S_v = [u for u in G.neighbors(v) if u in S]
            prod_term = 1.0
            for u in S_v:
                prod_term *= (1 - G[u][v]['weight'])
            NS_v = [u for u in G.neighbors(v) if u not in S]
            sum_term = sum(G[v][u]['weight'] for u in NS_v)
            scores[v] = prod_term * (1 + sum_term)
        best = max(scores, key=scores.get)
        print(f"Expected Benefit pick: {best}, score={scores[best]:.2f}")
        S.append(best)
    return S

random.seed(71)
N = G.number_of_nodes()
k = max(1, int(0.005 * N))
print(f"Total nodes: {N}, selecting k = {k} seeds...\n")
results = {}
# Out:
# Total nodes: 5242, selecting k = 26 seeds...

# %%
# CELF Greedy seed selection
t0 = time.perf_counter()
seeds_celf_greedy = celf_seeds(G, k, steps=20, mc_runs=20)
t1 = time.perf_counter()
spread_celf_greedy = estimate_spread(G, seeds_celf_greedy, steps=20, mc_runs=1000)
activated_nodes = independent_cascade(G, seeds_celf_greedy, steps=20)
results['CELF'] = (t1-t0, spread_celf_greedy)
print(f"\nCELF Greedy seeds: {seeds_celf_greedy}")
print(f"CELF Greedy selection time: {t1-t0:.2f} seconds")
print(f"Estimated spread (CELF Greedy): {spread_celf_greedy:.1f}\n")

plt.figure(figsize=(12, 12))
node_colors = []
for n in G.nodes():
    if n in seeds_celf_greedy:
        node_colors.append("red")
    elif n in activated_nodes:
        node_colors.append("orange")
    else:
        node_colors.append("lightgray")

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=5)
nx.draw_networkx_edges(G, pos, alpha=0.03)

plt.title(f"IC Spread from CELF Seeds ({len(activated_nodes)} nodes infected)", fontsize=16)
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# CELF round 1: pick 9639, marginal gain=1190.70
# CELF round 2: pick 3743, marginal gain=18.75
# CELF round 3: pick 8185, marginal gain=-2.60
# CELF round 4: pick 14807, marginal gain=-15.00
# CELF round 5: pick 18549, marginal gain=0.40
# CELF round 6: pick 10550, marginal gain=-12.90
# CELF round 7: pick 16994, marginal gain=15.40
# CELF round 8: pick 4774, marginal gain=-10.85
# CELF round 9: pick 18444, marginal gain=24.85
# CELF round 10: pick 12507, marginal gain=-6.05
# CELF round 11: pick 7042, marginal gain=2.60
# CELF round 12: pick 9892, marginal gain=35.15
# CELF round 13: pick 14009, marginal gain=-14.25
# CELF round 14: pick 9266, marginal gain=-11.00
# CELF round 15: pick 12074, marginal gain=19.65
# CELF round 16: pick 2001, marginal gain=-5.15
# CELF round 17: pick 5395, marginal gain=-10.80
# CELF round 18: pick 22371, marginal gain=19.50
# CELF round 19: pick 10026, marginal gain=-15.90
# CELF round 20: pick 14379, marginal gain=13.80
# CELF round 21: pick 25896, marginal gain=21.75
# CELF round 22: pick 18189, marginal gain=-1.45
# CELF round 23: pick 18996, marginal gain=-9.10
# CELF round 24: pick 6301, marginal gain=11.60
# CELF round 25: pick 9593, marginal gain=-4.30
# CELF round 26: pick 24718, marginal gain=-2.95
# Total re-evaluations: 5444 (should be ≪ k·n)
#
# CELF Greedy seeds: [9639, 3743, 8185, 14807, 18549, 10550, 16994, 4774, 18444, 12507, 7042, 9892, 14009, 9266, 12074, 2001, 5395, 22371, 10026, 14379, 25896, 18189, 18996, 6301, 9593, 24718]
# CELF Greedy selection time: -324.67 seconds
# Estimated spread (CELF Greedy): 1251.6

# %%
# d_greedy_seeds
t0 = time.perf_counter()
seeds_d_greedy = d_greedy_seeds(G, k, Rs=40)
t1 = time.perf_counter()
spread_d_greedy = estimate_spread(G, seeds_d_greedy, steps=20, mc_runs=1000)
activated_nodes = independent_cascade(G, seeds_d_greedy, steps=20)
results['D-greedy'] = (t1-t0, spread_d_greedy)
print(f"\nD-Greedy seeds: {seeds_d_greedy}")
print(f"D-Greedy selection time: {t1-t0:.2f} seconds")
print(f"Estimated spread (D-Greedy): {spread_d_greedy:.1f}\n")

plt.figure(figsize=(12, 12))
node_colors = []
for n in G.nodes():
    if n in seeds_d_greedy:
        node_colors.append("red")
    elif n in activated_nodes:
        node_colors.append("orange")
    else:
        node_colors.append("lightgray")

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=5)
nx.draw_networkx_edges(G, pos, alpha=0.03)

plt.title(f"IC Spread from CELF Seeds ({len(activated_nodes)} nodes infected)", fontsize=16)
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# D-greedy round 1: pick 19640, marginal gain=1172.20
# D-greedy round 2: pick 3824, marginal gain=25.15
# D-greedy round 3: pick 12885, marginal gain=22.05
# D-greedy round 4: pick 4488, marginal gain=14.15
# D-greedy round 5: pick 22320, marginal gain=12.65
# D-greedy round 6: pick 12720, marginal gain=8.70
# D-greedy round 7: pick 449, marginal gain=8.30
# D-greedy round 8: pick 12118, marginal gain=8.20
# D-greedy round 9: pick 24617, marginal gain=7.47
# D-greedy round 10: pick 14181, marginal gain=7.12
# D-greedy round 11: pick 593, marginal gain=7.03
# D-greedy round 12: pick 16469, marginal gain=6.42
# D-greedy round 13: pick 20765, marginal gain=6.22
# D-greedy round 14: pick 24330, marginal gain=6.17
# D-greedy round 15: pick 3811, marginal gain=6.03
# D-greedy round 16: pick 6857, marginal gain=6.00
# D-greedy round 17: pick 3716, marginal gain=5.38
# D-greedy round 18: pick 25931, marginal gain=5.25
# D-greedy round 19: pick 9591, marginal gain=5.22
# D-greedy round 20: pick 3345, marginal gain=5.20
# D-greedy round 21: pick 3193, marginal gain=5.12
# D-greedy round 22: pick 23488, marginal gain=5.12
# D-greedy round 23: pick 11293, marginal gain=4.88
# D-greedy round 24: pick 9020, marginal gain=4.88
# D-greedy round 25: pick 6337, marginal gain=4.75
# D-greedy round 26: pick 24877, marginal gain=4.67
#
# D-Greedy seeds: [19640, 3824, 12885, 4488, 22320, 12720, 449, 12118, 24617, 14181, 593, 16469, 20765, 24330, 3811, 6857, 3716, 25931, 9591, 3345, 3193, 23488, 11293, 9020, 6337, 24877]
# D-Greedy selection time: 467.25 seconds
# Estimated spread (D-Greedy): 1351.4

# %%
p = 0.2
for u, v in G.edges():
    G[u][v]['weight'] = p

random.seed(71)
steps = 40
N = G.number_of_nodes()
k = max(1, int(0.01 * N))
print(f"Total nodes: {N}, selecting k = {k} seeds...\n")
results = {}


# CELF Greedy seed selection
t0 = time.perf_counter()
seeds_celf_greedy = celf_seeds(G, k, steps=steps, mc_runs=20)
t1 = time.perf_counter()
spread_celf_greedy = estimate_spread(G, seeds_celf_greedy, steps=steps, mc_runs=1000)
results['CELF'] = (t1-t0, spread_celf_greedy)
print(f"\nCELF Greedy seeds: {seeds_celf_greedy}")
print(f"CELF Greedy selection time: {t1-t0:.2f} seconds")
print(f"Estimated spread (CELF Greedy): {spread_celf_greedy:.1f}\n")

# M-Greedy(with CELF) seed selection
t0 = time.perf_counter()
seeds_m_greedy = m_greedy_seeds(G, k, steps=steps, mc_runs=20)
t1 = time.perf_counter()
spread_m_greedy = estimate_spread(G, seeds_m_greedy, steps=steps, mc_runs=1000)
results['M-greedy'] = (t1-t0, spread_m_greedy)
print(f"\nM-Greedy seeds: {seeds_m_greedy}")
print(f"M-Greedy selection time: {t1-t0:.2f} seconds")
print(f"Estimated spread (M-Greedy): {spread_m_greedy:.1f}\n")

# D-Greedy seed selection
t0 = time.perf_counter()
seeds_d_greedy = d_greedy_seeds(G, k, Rs=40)
t1 = time.perf_counter()
spread_d_greedy = estimate_spread(G, seeds_d_greedy, steps=steps, mc_runs=1000)
results['D-greedy'] = (t1-t0, spread_d_greedy)
print(f"\nD-Greedy seeds: {seeds_d_greedy}")
print(f"D-Greedy selection time: {t1-t0:.2f} seconds")
print(f"Estimated spread (D-Greedy): {spread_d_greedy:.1f}\n")

# DegreeDiscountIC seed selection
t0 = time.perf_counter()
seeds_dd = degree_discount_ic(G, k, p)
t1 = time.perf_counter()
spread_dd = estimate_spread(G, seeds_dd, steps=steps, mc_runs=1000)
results['DegreeDiscount'] = (t1-t0, spread_dd)
print(f"DegreeDiscountIC seeds: {seeds_dd}")
print(f"Degree Discount selection time: {t1-t0:.2f} seconds")
print(f"Estimated spread (DegreeDiscount): {spread_dd:.1f}\n")

# Expected Benefit
t0 = time.perf_counter()
seeds_eb = expected_benefit_seeds(G, k)
t1 = time.perf_counter()
spread_eb = estimate_spread(G, seeds_eb, steps=steps, mc_runs=1000)
results['ExpectedBenefit'] = (t1-t0, spread_eb)
print(f"Expected Benefit seeds: {seeds_eb}")
print(f"Expected Benefit selection time: {t1-t0:.2f} seconds")
print(f"Estimated spread (Expected Benefit): {spread_eb:.1f}\n")

# Compare results
for method, (sel_time, spread) in results.items():
    print(f"{method}: selection_time={sel_time:.2f}s, spread={spread:.1f}")
methods = ['CELFGreedy', 'M-Greedy', 'D-greedy', 'DegreeDiscount','ExpectedBenefit']
spreads = [spread_celf_greedy, spread_m_greedy, spread_d_greedy, spread_dd, spread_eb]
plt.bar(methods, spreads)
plt.ylabel('Average # of activated nodes')
plt.title('Seed Selection Comparison')
plt.show()
# Out:
# Total nodes: 5242, selecting k = 52 seeds...
#
# CELF round 1: pick 21847, marginal gain=1218.00
# CELF round 2: pick 4967, marginal gain=8.35
# CELF round 3: pick 6076, marginal gain=-9.05
# CELF round 4: pick 3939, marginal gain=-6.70
# CELF round 5: pick 6271, marginal gain=-8.70
# CELF round 6: pick 7511, marginal gain=14.15
# CELF round 7: pick 4588, marginal gain=-13.50
# CELF round 8: pick 22901, marginal gain=-11.40
# CELF round 9: pick 24126, marginal gain=43.80
# CELF round 10: pick 11011, marginal gain=-12.55
# CELF round 11: pick 882, marginal gain=8.60
# CELF round 12: pick 18487, marginal gain=-3.70
# CELF round 13: pick 12678, marginal gain=-5.15
# CELF round 14: pick 22734, marginal gain=-1.70
# CELF round 15: pick 3136, marginal gain=4.50
# CELF round 16: pick 5545, marginal gain=-9.40
# CELF round 17: pick 19140, marginal gain=20.75
# CELF round 18: pick 17824, marginal gain=-13.95
# CELF round 19: pick 20001, marginal gain=19.70
# CELF round 20: pick 25439, marginal gain=27.95
# CELF round 21: pick 11416, marginal gain=-12.15
# CELF round 22: pick 25108, marginal gain=19.75
# CELF round 23: pick 7824, marginal gain=-9.05
# CELF round 24: pick 3910, marginal gain=32.50
# CELF round 25: pick 17337, marginal gain=-13.80
# CELF round 26: pick 2526, marginal gain=-7.85
# CELF round 27: pick 7093, marginal gain=15.35
# CELF round 28: pick 2984, marginal gain=2.45
# CELF round 29: pick 10427, marginal gain=-14.10
# CELF round 30: pick 15372, marginal gain=28.30
# CELF round 31: pick 11841, marginal gain=-11.20
# CELF round 32: pick 17393, marginal gain=-14.65
# CELF round 33: pick 869, marginal gain=12.85
# CELF round 34: pick 12704, marginal gain=-1.05
# CELF round 35: pick 3877, marginal gain=8.00
# CELF round 36: pick 18399, marginal gain=-7.15
# CELF round 37: pick 6229, marginal gain=-0.75
# CELF round 38: pick 23304, marginal gain=-9.10
# CELF round 39: pick 1172, marginal gain=9.75
# CELF round 40: pick 396, marginal gain=23.20
# CELF round 41: pick 385, marginal gain=3.35
# CELF round 42: pick 17249, marginal gain=-1.55
# CELF round 43: pick 1765, marginal gain=-0.05
# CELF round 44: pick 20250, marginal gain=2.65
# CELF round 45: pick 20261, marginal gain=-11.20
# CELF round 46: pick 14638, marginal gain=-4.50
# CELF round 47: pick 17817, marginal gain=18.65
# CELF round 48: pick 21861, marginal gain=-6.45
# CELF round 49: pick 9758, marginal gain=-6.95
# CELF round 50: pick 23168, marginal gain=-14.50
# CELF round 51: pick 4451, marginal gain=0.80
# CELF round 52: pick 16971, marginal gain=11.45
# Total re-evaluations: 5342 (should be ≪ k·n)
#
# CELF Greedy seeds: [21847, 4967, 6076, 3939, 6271, 7511, 4588, 22901, 24126, 11011, 882, 18487, 12678, 22734, 3136, 5545, 19140, 17824, 20001, 25439, 11416, 25108, 7824, 3910, 17337, 2526, 7093, 2984, 10427, 15372, 11841, 17393, 869, 12704, 3877, 18399, 6229, 23304, 1172, 396, 385, 17249, 1765, 20250, 20261, 14638, 17817, 21861, 9758, 23168, 4451, 16971]
# CELF Greedy selection time: 395.17 seconds
# Estimated spread (CELF Greedy): 1321.2
#
# CELF round 1: pick 18778, marginal gain=880.80
# CELF round 2: pick 1293, marginal gain=37.60
# CELF round 3: pick 7911, marginal gain=-1.65
# CELF round 4: pick 18870, marginal gain=-3.95
# CELF round 5: pick 18724, marginal gain=1.55
# CELF round 6: pick 4639, marginal gain=-5.75
# CELF round 7: pick 23095, marginal gain=11.70
# CELF round 8: pick 14377, marginal gain=8.25
# CELF round 9: pick 7459, marginal gain=-5.30
# CELF round 10: pick 4146, marginal gain=2.80
# CELF round 11: pick 13142, marginal gain=-3.80
# CELF round 12: pick 17172, marginal gain=13.60
# CELF round 13: pick 15145, marginal gain=-0.60
# CELF round 14: pick 9895, marginal gain=-3.45
# CELF round 15: pick 25050, marginal gain=4.80
# CELF round 16: pick 21968, marginal gain=-4.00
# CELF round 17: pick 5065, marginal gain=-6.60
# CELF round 18: pick 9769, marginal gain=-2.65
# CELF round 19: pick 12110, marginal gain=18.80
# CELF round 20: pick 7719, marginal gain=-5.50
# CELF round 21: pick 22887, marginal gain=-5.55
# CELF round 22: pick 3178, marginal gain=-5.85
# CELF round 23: pick 18517, marginal gain=14.35
# CELF round 24: pick 9862, marginal gain=7.00
# CELF round 25: pick 9639, marginal gain=12.35
# CELF round 26: pick 1386, marginal gain=-0.10
# CELF round 27: pick 7307, marginal gain=-5.65
# CELF round 28: pick 20595, marginal gain=-7.45
# CELF round 29: pick 22177, marginal gain=3.20
# CELF round 30: pick 22105, marginal gain=-4.15
# CELF round 31: pick 5608, marginal gain=4.50
# CELF round 32: pick 12606, marginal gain=-8.30
# CELF round 33: pick 7899, marginal gain=-2.75
# CELF round 34: pick 16148, marginal gain=-6.25
# CELF round 35: pick 15457, marginal gain=21.90
# CELF round 36: pick 8374, marginal gain=16.45
# CELF round 37: pick 22903, marginal gain=-9.65
# CELF round 38: pick 10158, marginal gain=4.60
# CELF round 39: pick 9025, marginal gain=5.55
# CELF round 40: pick 24924, marginal gain=-7.00
# CELF round 41: pick 23470, marginal gain=-1.45
# CELF round 42: pick 7013, marginal gain=-10.05
# CELF round 43: pick 10519, marginal gain=7.60
# CELF round 44: pick 7504, marginal gain=2.05
# CELF round 45: pick 1667, marginal gain=8.15
# CELF round 46: pick 20052, marginal gain=17.50
# CELF round 47: pick 13369, marginal gain=-3.50
# CELF round 48: pick 2912, marginal gain=-1.15
# CELF round 49: pick 5352, marginal gain=-4.30
# CELF round 50: pick 17944, marginal gain=8.45
# CELF round 51: pick 7956, marginal gain=-8.55
# CELF round 52: pick 15829, marginal gain=5.40
# Total re-evaluations: 2074 (should be ≪ k·n)
#
# M-Greedy seeds: [18778, 1293, 7911, 18870, 18724, 4639, 23095, 14377, 7459, 4146, 13142, 17172, 15145, 9895, 25050, 21968, 5065, 9769, 12110, 7719, 22887, 3178, 18517, 9862, 9639, 1386, 7307, 20595, 22177, 22105, 5608, 12606, 7899, 16148, 15457, 8374, 22903, 10158, 9025, 24924, 23470, 7013, 10519, 7504, 1667, 20052, 13369, 2912, 5352, 17944, 7956, 15829]
# M-Greedy selection time: 227.05 seconds
# Estimated spread (M-Greedy): 1295.5
#
# D-greedy round 1: pick 20511, marginal gain=1145.50
# D-greedy round 2: pick 7650, marginal gain=29.30
# D-greedy round 3: pick 6583, marginal gain=24.07
# D-greedy round 4: pick 4364, marginal gain=14.75
# D-greedy round 5: pick 9764, marginal gain=12.70
# D-greedy round 6: pick 14430, marginal gain=11.72
# D-greedy round 7: pick 449, marginal gain=9.53
# D-greedy round 8: pick 12118, marginal gain=8.88
# D-greedy round 9: pick 7541, marginal gain=8.80
# D-greedy round 10: pick 2410, marginal gain=7.85
# D-greedy round 11: pick 492, marginal gain=7.35
# D-greedy round 12: pick 1493, marginal gain=7.25
# D-greedy round 13: pick 9017, marginal gain=7.17
# D-greedy round 14: pick 593, marginal gain=6.88
# D-greedy round 15: pick 3113, marginal gain=6.67
# D-greedy round 16: pick 21629, marginal gain=6.20
# D-greedy round 17: pick 11379, marginal gain=6.20
# D-greedy round 18: pick 3345, marginal gain=6.08
# D-greedy round 19: pick 2072, marginal gain=5.80
# D-greedy round 20: pick 185, marginal gain=5.53
# D-greedy round 21: pick 9591, marginal gain=5.28
# D-greedy round 22: pick 543, marginal gain=5.22
# D-greedy round 23: pick 18122, marginal gain=5.15
# D-greedy round 24: pick 24330, marginal gain=5.12
# D-greedy round 25: pick 23093, marginal gain=5.08
# D-greedy round 26: pick 15678, marginal gain=5.00
# D-greedy round 27: pick 19048, marginal gain=4.88
# D-greedy round 28: pick 2797, marginal gain=4.85
# D-greedy round 29: pick 15357, marginal gain=4.65
# D-greedy round 30: pick 21125, marginal gain=4.62
# D-greedy round 31: pick 21089, marginal gain=4.55
# D-greedy round 32: pick 11557, marginal gain=4.50
# D-greedy round 33: pick 22046, marginal gain=4.35
# D-greedy round 34: pick 24781, marginal gain=4.35
# D-greedy round 35: pick 3716, marginal gain=4.35
# D-greedy round 36: pick 22318, marginal gain=4.28
# D-greedy round 37: pick 18621, marginal gain=4.22
# D-greedy round 38: pick 5655, marginal gain=4.20
# D-greedy round 39: pick 11293, marginal gain=4.17
# D-greedy round 40: pick 6337, marginal gain=4.12
# D-greedy round 41: pick 12212, marginal gain=3.80
# D-greedy round 42: pick 11052, marginal gain=3.75
# D-greedy round 43: pick 9037, marginal gain=3.73
# D-greedy round 44: pick 5078, marginal gain=3.65
# D-greedy round 45: pick 6350, marginal gain=3.62
# D-greedy round 46: pick 22483, marginal gain=3.60
# D-greedy round 47: pick 1736, marginal gain=3.60
# D-greedy round 48: pick 17501, marginal gain=3.55
# D-greedy round 49: pick 19404, marginal gain=3.55
# D-greedy round 50: pick 16154, marginal gain=3.50
# D-greedy round 51: pick 1817, marginal gain=3.45
# D-greedy round 52: pick 1981, marginal gain=3.45
#
# D-Greedy seeds: [20511, 7650, 6583, 4364, 9764, 14430, 449, 12118, 7541, 2410, 492, 1493, 9017, 593, 3113, 21629, 11379, 3345, 2072, 185, 9591, 543, 18122, 24330, 23093, 15678, 19048, 2797, 15357, 21125, 21089, 11557, 22046, 24781, 3716, 22318, 18621, 5655, 11293, 6337, 12212, 11052, 9037, 5078, 6350, 22483, 1736, 17501, 19404, 16154, 1817, 1981]
# D-Greedy selection time: 1196.66 seconds
# Estimated spread (D-Greedy): 1448.3
#
# DegreeDiscountIC seeds: [21012, 21281, 15244, 13929, 13801, 22691, 2654, 6512, 14265, 22601, 7650, 2710, 23038, 4364, 7689, 6264, 9639, 10762, 449, 5052, 13142, 9017, 14157, 3651, 676, 23614, 19865, 7007, 1000, 6583, 1217, 9471, 4511, 6700, 1488, 24057, 10350, 6271, 24814, 22177, 9184, 6823, 15066, 4952, 9710, 24330, 5901, 16594, 15300, 11275, 11696, 11372]
# Degree Discount selection time: 0.09 seconds
# Estimated spread (DegreeDiscount): 1335.2
#
# Expected Benefit pick: 21012, score=17.20
# Expected Benefit pick: 21281, score=13.28
# Expected Benefit pick: 15244, score=12.80
# Expected Benefit pick: 22691, score=10.24
# Expected Benefit pick: 13929, score=10.00
# Expected Benefit pick: 13801, score=10.00
# Expected Benefit pick: 2654, score=8.60
# Expected Benefit pick: 6512, score=8.48
# Expected Benefit pick: 14265, score=8.40
# Expected Benefit pick: 22601, score=8.40
# Expected Benefit pick: 7650, score=8.40
# Expected Benefit pick: 2710, score=7.60
# Expected Benefit pick: 23038, score=7.60
# Expected Benefit pick: 4364, score=7.60
# Expected Benefit pick: 7689, score=7.40
# Expected Benefit pick: 6264, score=7.40
# Expected Benefit pick: 9639, score=7.20
# Expected Benefit pick: 21508, score=7.07
# Expected Benefit pick: 10762, score=7.00
# Expected Benefit pick: 449, score=7.00
# Expected Benefit pick: 5052, score=6.80
# Expected Benefit pick: 13142, score=6.60
# Expected Benefit pick: 9017, score=6.60
# Expected Benefit pick: 14157, score=6.56
# Expected Benefit pick: 3651, score=6.24
# Expected Benefit pick: 676, score=6.20
# Expected Benefit pick: 23614, score=6.20
# Expected Benefit pick: 19865, score=6.20
# Expected Benefit pick: 7007, score=6.00
# Expected Benefit pick: 1000, score=6.00
# Expected Benefit pick: 6583, score=6.00
# Expected Benefit pick: 10350, score=5.89
# Expected Benefit pick: 1217, score=5.80
# Expected Benefit pick: 9471, score=5.80
# Expected Benefit pick: 6700, score=5.60
# Expected Benefit pick: 1488, score=5.60
# Expected Benefit pick: 24057, score=5.60
# Expected Benefit pick: 6271, score=5.44
# Expected Benefit pick: 2741, score=5.41
# Expected Benefit pick: 24814, score=5.20
# Expected Benefit pick: 22177, score=5.20
# Expected Benefit pick: 9184, score=5.20
# Expected Benefit pick: 6823, score=5.20
# Expected Benefit pick: 15066, score=5.20
# Expected Benefit pick: 4952, score=5.12
# Expected Benefit pick: 9710, score=5.00
# Expected Benefit pick: 24330, score=5.00
# Expected Benefit pick: 4834, score=4.99
# Expected Benefit pick: 5901, score=4.96
# Expected Benefit pick: 15300, score=4.80
# Expected Benefit pick: 11275, score=4.80
# Expected Benefit pick: 11696, score=4.80
# Expected Benefit seeds: [21012, 21281, 15244, 22691, 13929, 13801, 2654, 6512, 14265, 22601, 7650, 2710, 23038, 4364, 7689, 6264, 9639, 21508, 10762, 449, 5052, 13142, 9017, 14157, 3651, 676, 23614, 19865, 7007, 1000, 6583, 10350, 1217, 9471, 6700, 1488, 24057, 6271, 2741, 24814, 22177, 9184, 6823, 15066, 4952, 9710, 24330, 4834, 5901, 15300, 11275, 11696]
# Expected Benefit selection time: 1.49 seconds
# Estimated spread (Expected Benefit): 1331.8
#
# CELF: selection_time=395.17s, spread=1321.2
# M-greedy: selection_time=227.05s, spread=1295.5
# D-greedy: selection_time=1196.66s, spread=1448.3
# DegreeDiscount: selection_time=0.09s, spread=1335.2
# ExpectedBenefit: selection_time=1.49s, spread=1331.8

# %% [markdown]
# Linear Threshold Model

# %%
common_num = {}
for u, v in G.edges():
    cn = len(set(G.neighbors(u)).intersection(G.neighbors(v)))
    common_num[(u, v)] = cn
    common_num[(v, u)] = cn  # 无向图

# 2. 对每个节点 v 做归一化，得到最终权重 w(u,v)
for v in G.nodes():
    nbrs = list(G.neighbors(v))
    total = sum(common_num[(u, v)] for u in nbrs)
    if total == 0:
        # 若所有公共邻居数都为 0，就退化为 1/deg(v)
        for u in nbrs:
            G[u][v]['weight'] = 1.0 / len(nbrs)
    else:
        for u in nbrs:
            G[u][v]['weight'] = common_num[(u, v)] / total

# 3. 定义 LT 模型的激活函数（示例：一次简单迭代模拟）
def linear_threshold(G, seeds, steps=10):
    activated = set(seeds)
    # 每个节点随机抽取阈值
    theta = {v: random.random() for v in G.nodes()}
    for step in range(steps):
        new_activated = []
        for v in G.nodes():
            if v in activated:
                continue
            # 计算累计影响 ∑_{u∈activated∩N(v)} w(u,v)
            influence = sum(G[u][v]['weight'] for u in G.neighbors(v) if u in activated)
            if influence >= theta[v]:
                new_activated.append(v)
        if not new_activated:
            break
        activated.update(new_activated)
    return activated

def estimate_spread_LT(G, seeds, steps=10, mc_runs=100):
    """
    对给定种子集 seeds，重复执行 LT 模拟 mc_runs 次，返回平均激活节点数。
    """
    total = 0
    for _ in range(mc_runs):
        total += len(linear_threshold(G, seeds, steps))
    return total / mc_runs

def celf_seeds_LT(G, k, steps=10, mc_runs=100):
    """
    在 LT 模型下，使用 CELF 策略选取 k 个种子节点。
    G: 带 'weight' 属性的有向图
    k: 要选择的种子数量
    steps, mc_runs: LT 仿真的参数
    返回：选出的种子列表 S
    """
    # 初始化堆 (gain 的负值, 节点, 上次计算轮次)
    heap = []
    for v in G.nodes():
        spread_v = estimate_spread_LT(G, [v], steps, mc_runs)
        heap.append((-spread_v, v, 0))
    heapq.heapify(heap)

    S = []
    spread_S = 0.0
    lookups = 0

    for round_i in range(1, k + 1):
        while True:
            neg_gain, v, prev_round = heapq.heappop(heap)
            gain = -neg_gain
            # 如果上次计算 v 的增益是在上一轮完成的，则无需重算
            if prev_round == round_i - 1:
                S.append(v)
                spread_S += gain
                print(f"CELF-LT round {round_i}: pick {v}, marginal gain={gain:.2f}")
                break
            else:
                # 重新评估 v 的边际增益
                lookups += 1
                new_spread = estimate_spread_LT(G, S + [v], steps, mc_runs)
                new_gain = new_spread - spread_S
                heapq.heappush(heap, (-new_gain, v, round_i - 1))

    print(f"Total re-evaluations: {lookups}")
    return S

# %%
random.seed(71)
N = G.number_of_nodes()
k = max(1, int(0.01 * N))
print(f"Total nodes: {N}, selecting k = {k} seeds...\n")
results = {}

# CELF Greedy seed selection
t0 = time.perf_counter()
seeds_celf_greedy = celf_seeds_LT(G, k, steps=20, mc_runs=1)
t1 = time.perf_counter()
spread_celf_greedy = estimate_spread_LT(G, seeds_celf_greedy, steps=20, mc_runs=10)
activated_nodes = linear_threshold(G, seeds_celf_greedy, steps=20)
results['CELF'] = (t1-t0, activated_nodes)
print(f"\nCELF Greedy seeds: {seeds_celf_greedy}")
print(f"CELF Greedy selection time: {t1-t0:.2f} seconds")
print(f"Estimated spread (CELF Greedy): {spread_celf_greedy:.1f}\n")

plt.figure(figsize=(10, 10))
node_colors = []
for n in G.nodes():
    if n in seeds_celf_greedy:
        node_colors.append("red")
    elif n in activated_nodes:
        node_colors.append("orange")
    else:
        node_colors.append("lightgray")

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=5)
nx.draw_networkx_edges(G, pos, alpha=0.03)

plt.title(f"LT Spread from CELF Seeds ({len(activated_nodes)} nodes infected)", fontsize=16)
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Total nodes: 5242, selecting k = 52 seeds...
#
# CELF-LT round 1: pick 18208, marginal gain=1073.00
# CELF-LT round 2: pick 13831, marginal gain=5.00
# CELF-LT round 3: pick 7632, marginal gain=150.00
# CELF-LT round 4: pick 3878, marginal gain=-67.00
# CELF-LT round 5: pick 19954, marginal gain=-217.00
# CELF-LT round 6: pick 22336, marginal gain=-183.00
# CELF-LT round 7: pick 3033, marginal gain=210.00
# CELF-LT round 8: pick 14485, marginal gain=-128.00
# CELF-LT round 9: pick 6082, marginal gain=-24.00
# CELF-LT round 10: pick 23363, marginal gain=-51.00
# CELF-LT round 11: pick 23134, marginal gain=253.00
# CELF-LT round 12: pick 11372, marginal gain=4.00
# CELF-LT round 13: pick 19475, marginal gain=72.00
# CELF-LT round 14: pick 2506, marginal gain=-228.00
# CELF-LT round 15: pick 15145, marginal gain=340.00
# CELF-LT round 16: pick 20667, marginal gain=-235.00
# CELF-LT round 17: pick 16224, marginal gain=-43.00
# CELF-LT round 18: pick 4416, marginal gain=-94.00
# CELF-LT round 19: pick 22691, marginal gain=142.00
# CELF-LT round 20: pick 11215, marginal gain=-244.00
# CELF-LT round 21: pick 16056, marginal gain=172.00
# CELF-LT round 22: pick 10623, marginal gain=416.00
# CELF-LT round 23: pick 20309, marginal gain=-70.00
# CELF-LT round 24: pick 3858, marginal gain=127.00
# CELF-LT round 25: pick 19167, marginal gain=-243.00
# CELF-LT round 26: pick 19640, marginal gain=158.00
# CELF-LT round 27: pick 11026, marginal gain=15.00
# CELF-LT round 28: pick 1024, marginal gain=-166.00
# CELF-LT round 29: pick 3633, marginal gain=184.00
# CELF-LT round 30: pick 24835, marginal gain=-73.00
# CELF-LT round 31: pick 14842, marginal gain=-105.00
# CELF-LT round 32: pick 10501, marginal gain=-187.00
# CELF-LT round 33: pick 16335, marginal gain=447.00
# CELF-LT round 34: pick 2997, marginal gain=-33.00
# CELF-LT round 35: pick 17804, marginal gain=-126.00
# CELF-LT round 36: pick 24454, marginal gain=119.00
# CELF-LT round 37: pick 13970, marginal gain=-64.00
# CELF-LT round 38: pick 13837, marginal gain=174.00
# CELF-LT round 39: pick 15974, marginal gain=-176.00
# CELF-LT round 40: pick 7824, marginal gain=-105.00
# CELF-LT round 41: pick 15616, marginal gain=-142.00
# CELF-LT round 42: pick 25902, marginal gain=271.00
# CELF-LT round 43: pick 14403, marginal gain=223.00
# CELF-LT round 44: pick 24944, marginal gain=-101.00
# CELF-LT round 45: pick 2449, marginal gain=-118.00
# CELF-LT round 46: pick 3196, marginal gain=23.00
# CELF-LT round 47: pick 15960, marginal gain=61.00
# CELF-LT round 48: pick 3032, marginal gain=-47.00
# CELF-LT round 49: pick 13929, marginal gain=34.00
# CELF-LT round 50: pick 4102, marginal gain=20.00
# CELF-LT round 51: pick 16906, marginal gain=-119.00
# CELF-LT round 52: pick 3279, marginal gain=-16.00
# Total re-evaluations: 5331
#
# CELF Greedy seeds: [18208, 13831, 7632, 3878, 19954, 22336, 3033, 14485, 6082, 23363, 23134, 11372, 19475, 2506, 15145, 20667, 16224, 4416, 22691, 11215, 16056, 10623, 20309, 3858, 19167, 19640, 11026, 1024, 3633, 24835, 14842, 10501, 16335, 2997, 17804, 24454, 13970, 13837, 15974, 7824, 15616, 25902, 14403, 24944, 2449, 3196, 15960, 3032, 13929, 4102, 16906, 3279]
# CELF Greedy selection time: 285.37 seconds
# Estimated spread (CELF Greedy): 1315.2

# %% [markdown]
# Discrete Time SI + Multi-hop Decay Model

# %%
def discrete_SI_with_attenuation(G, seeds, alpha=0.8, steps=10):
    """
    Discrete-time SI 模型 + 多跳衰减，且每一时隙所有已激活节点都尝试激活邻居，带多跳衰减。
    G: NetworkX Graph，边上 attribute 'weight' 为基础概率 p_uv。
    seeds: 初始激活节点列表。
    alpha: 每跳衰减因子 (0 < alpha <= 1)。节点 u 在第 hop_u 跳时，用 p_uv * alpha^(hop_u-1) 去激活邻居。
    steps: 最大模拟轮数。
    返回：最终被激活的节点集合（set）。
    """

    activated = set(seeds)
    node_hop = {s: 1 for s in seeds}
    
    for _ in range(steps):
        next_new = []
        # 在每个时隙，对 G 中所有已激活节点 u 做尝试
        for u in list(activated):
            hop_u = node_hop[u]
            for v in G.neighbors(u):
                if v not in activated:
                    p_eff = G[u][v]['weight'] * (alpha ** (hop_u - 1))
                    if random.random() <= p_eff:
                        activated.add(v)
                        node_hop[v] = hop_u + 1
                        next_new.append(v)
        if not next_new:
            break
    
    return activated

# ——— 2. Monte Carlo 估算传播规模 ———
def estimate_spread_DSIA(G, seeds, alpha=0.8, steps=10, mc_runs=100):
    """
    对给定种子集 seeds，在 Discrete‐time SI + 多跳衰减 模型下重复 mc_runs 次仿真，
    返回所有仿真平均激活节点数。
    """
    total = 0
    for _ in range(mc_runs):
        total += len(discrete_SI_with_attenuation(G, seeds, alpha, steps))
    return total / mc_runs

# ——— 3. CELF 优化的 Greedy 选种（基于 DSIA + Monte Carlo） ———
def celf_seeds_DSIA(G, k, alpha=0.8, steps=10, mc_runs=10):
    """
    使用 CELF 策略在 Discrete‐time SI + 多跳衰减 上选取 k 个种子。
    G: 无向图，边上 'weight' 为基础概率 p_uv。
    k: 种子数目
    alpha: 衰减因子
    steps, mc_runs: DSIA 仿真参数
    返回：选出的种子列表 S
    """
    # 1. 初始化堆：对每个节点 v 先估算 singleton {v} 的扩散规模
    heap = []
    for v in G.nodes():
        spread_v = estimate_spread_DSIA(G, [v], alpha, steps, mc_runs)
        # 堆里存 (-gain, 节点, 上次计算轮次)
        heap.append((-spread_v, v, 0))
    heapq.heapify(heap)

    S = []
    spread_S = 0.0     # 当前种子集的估计传播规模
    lookups = 0        # 重新评估次数统计

    # 2. 依次选 k 个种子
    for round_i in range(1, k + 1):
        while True:
            neg_gain, v, prev_round = heapq.heappop(heap)
            gain = -neg_gain
            # 如果上次计算是在上一轮 round_i-1 完成的，则直接接受 v
            if prev_round == round_i - 1:
                S.append(v)
                spread_S += gain
                print(f"CELF-DSIA round {round_i}: pick {v}, marginal gain={gain:.2f}")
                break
            else:
                # 否则，重新估算 v 加入当前 S 后的增益
                lookups += 1
                new_spread = estimate_spread_DSIA(G, S + [v], alpha, steps, mc_runs)
                new_gain = new_spread - spread_S
                # 更新堆项，标记本次计算发生在 round_i-1
                heapq.heappush(heap, (-new_gain, v, round_i - 1))

    print(f"Total re-evaluations: {lookups}")
    return S

# %%
p = 0.2
for u, v in G.edges():
    G[u][v]['weight'] = p

random.seed(71)
N = G.number_of_nodes()
alpha = 0.9
steps = 20
k = max(1, int(0.01 * N))
print(f"Total nodes: {N}, selecting k = {k} seeds...\n")
results = {}

# CELF Greedy seed selection
t0 = time.perf_counter()
seeds_celf_greedy = celf_seeds_DSIA(G, k, alpha=alpha, steps=steps, mc_runs=5)
t1 = time.perf_counter()
spread_celf_greedy = estimate_spread_DSIA(G, seeds_celf_greedy, alpha=alpha, steps=steps, mc_runs=100)
activated_nodes = discrete_SI_with_attenuation(G, seeds_celf_greedy, alpha=alpha, steps=steps)
results['CELF'] = (t1-t0, spread_celf_greedy)
print(f"\nCELF Greedy seeds: {seeds_celf_greedy}")
print(f"CELF Greedy selection time: {t1-t0:.2f} seconds")
print(f"Estimated spread (CELF Greedy): {spread_celf_greedy:.1f}\n")

plt.figure(figsize=(10, 10))
node_colors = []
for n in G.nodes():
    if n in seeds_celf_greedy:
        node_colors.append("red")
    elif n in activated_nodes:
        node_colors.append("orange")
    else:
        node_colors.append("lightgray")

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=5)
nx.draw_networkx_edges(G, pos, alpha=0.03)

plt.title(f"Discrete SI Spread from CELF Seeds ({len(activated_nodes)} nodes infected)", fontsize=16)
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Total nodes: 5242, selecting k = 52 seeds...
#
# CELF-DSIA round 1: pick 17655, marginal gain=3472.60
# CELF-DSIA round 2: pick 14599, marginal gain=141.20
# CELF-DSIA round 3: pick 7689, marginal gain=89.60
# CELF-DSIA round 4: pick 7307, marginal gain=53.80
# CELF-DSIA round 5: pick 21754, marginal gain=16.00
# CELF-DSIA round 6: pick 17207, marginal gain=4.60
# CELF-DSIA round 7: pick 1006, marginal gain=4.40
# CELF-DSIA round 8: pick 2215, marginal gain=11.20
# CELF-DSIA round 9: pick 17297, marginal gain=4.20
# CELF-DSIA round 10: pick 1545, marginal gain=9.20
# CELF-DSIA round 11: pick 5545, marginal gain=5.40
# CELF-DSIA round 12: pick 23214, marginal gain=7.80
# CELF-DSIA round 13: pick 9189, marginal gain=12.20
# CELF-DSIA round 14: pick 8457, marginal gain=0.60
# CELF-DSIA round 15: pick 25777, marginal gain=2.20
# CELF-DSIA round 16: pick 3522, marginal gain=-6.80
# CELF-DSIA round 17: pick 2136, marginal gain=-4.80
# CELF-DSIA round 18: pick 12614, marginal gain=-0.40
# CELF-DSIA round 19: pick 24718, marginal gain=10.20
# CELF-DSIA round 20: pick 5407, marginal gain=13.20
# CELF-DSIA round 21: pick 17266, marginal gain=-8.60
# CELF-DSIA round 22: pick 17843, marginal gain=8.80
# CELF-DSIA round 23: pick 19023, marginal gain=-1.40
# CELF-DSIA round 24: pick 23810, marginal gain=-2.80
# CELF-DSIA round 25: pick 25609, marginal gain=6.00
# CELF-DSIA round 26: pick 163, marginal gain=-0.20
# CELF-DSIA round 27: pick 6512, marginal gain=-7.60
# CELF-DSIA round 28: pick 11400, marginal gain=-4.00
# CELF-DSIA round 29: pick 12545, marginal gain=14.40
# CELF-DSIA round 30: pick 17670, marginal gain=22.60
# CELF-DSIA round 31: pick 252, marginal gain=-1.80
# CELF-DSIA round 32: pick 2410, marginal gain=-7.60
# CELF-DSIA round 33: pick 3178, marginal gain=12.60
# CELF-DSIA round 34: pick 5392, marginal gain=11.40
# CELF-DSIA round 35: pick 8155, marginal gain=-9.00
# CELF-DSIA round 36: pick 17114, marginal gain=-8.40
# CELF-DSIA round 37: pick 18783, marginal gain=-6.40
# CELF-DSIA round 38: pick 20373, marginal gain=38.20
# CELF-DSIA round 39: pick 21646, marginal gain=-4.80
# CELF-DSIA round 40: pick 25902, marginal gain=-3.60
# CELF-DSIA round 41: pick 11213, marginal gain=5.60
# CELF-DSIA round 42: pick 13032, marginal gain=6.00
# CELF-DSIA round 43: pick 14498, marginal gain=-8.00
# CELF-DSIA round 44: pick 16310, marginal gain=2.60
# CELF-DSIA round 45: pick 16963, marginal gain=-0.80
# CELF-DSIA round 46: pick 18909, marginal gain=1.40
# CELF-DSIA round 47: pick 22979, marginal gain=8.40
# CELF-DSIA round 48: pick 26021, marginal gain=-0.80
# CELF-DSIA round 49: pick 3516, marginal gain=3.80
# CELF-DSIA round 50: pick 17750, marginal gain=1.80
# CELF-DSIA round 51: pick 14430, marginal gain=0.00
# CELF-DSIA round 52: pick 1023, marginal gain=9.80
# Total re-evaluations: 6442
#
# CELF Greedy seeds: [17655, 14599, 7689, 7307, 21754, 17207, 1006, 2215, 17297, 1545, 5545, 23214, 9189, 8457, 25777, 3522, 2136, 12614, 24718, 5407, 17266, 17843, 19023, 23810, 25609, 163, 6512, 11400, 12545, 17670, 252, 2410, 3178, 5392, 8155, 17114, 18783, 20373, 21646, 25902, 11213, 13032, 14498, 16310, 16963, 18909, 22979, 26021, 3516, 17750, 14430, 1023]
# CELF Greedy selection time: 1067.06 seconds
# Estimated spread (CELF Greedy): 3916.3
